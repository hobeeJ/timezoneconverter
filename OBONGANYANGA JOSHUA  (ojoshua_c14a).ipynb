# %%
import datetime
from datetime import time
import calendar

# %%
countryTimes = {'Abidjan':0,
'Accra':0,
'Acre':-18000,
'ACT':36000,
'Adak':-36000,
'Addis_Ababa':10800,
'Adelaide':34200,
'Aden':10800,
'Alaska':-32400,
'Aleutian':-36000,
'Algiers':3600,
'Almaty':21600,
'Amman':7200,
'Amsterdam':3600,
'Anadyr':43200,
'Anchorage':-32400,
'Andorra':3600,
'Anguilla':-14400,
'Antananarivo':10800,
'Antigua':-14400,
'Apia':46800,
'Aqtau':18000,
'Aqtobe':18000,
'Araguaina':-10800,
'Arizona':-25200,
'Aruba':-14400,
'Ashgabat':18000,
'Ashkhabad':18000,
'Asmara':10800,
'Asmera':10800,
'Asuncion':-10800,
'Athens':7200,
'Atikokan':-18000,
'Atka':-36000,
'Atlantic':-14400,
'Auckland':43200,
'Azores':-3600,
'Baghdad':10800,
'Bahia':-10800,
'Bahia_Banderas':-21600,
'Bahrain':10800,
'BajaNorte':-28800,
'BajaSur':-25200,
'Baku':14400,
'Bamako':0,
'Bangkok':25200,
'Bangui':3600,
'Banjul':0,
'Barbados':-14400,
'Beirut':7200,
'Belem':-10800,
'Belfast':0,
'Belgrade':3600,
'Belize':-21600,
'Berlin':3600,
'Bermuda':-14400,
'Beulah':-21600,
'Bishkek':21600,
'Bissau':0,
'Blanc-Sablon':-14400,
'Blantyre':7200,
'Boa_Vista':-14400,
'Bogota':-18000,
'Boise':-25200,
'Bougainville':39600,
'Bratislava':3600,
'Brazzaville':3600,
'Brisbane':36000,
'Broken_Hill':34200,
'Brunei':28800,
'Brussels':3600,
'Bucharest':7200,
'Budapest':3600,
'Buenos_Aires':-10800,
'Bujumbura':7200,
'Busingen':3600,
'Cairo':7200,
'Calcutta':19800,
'Cambridge_Bay':-25200,
'Campo_Grande':-14400,
'Canary':0,
'Canberra':36000,
'Cancun':-18000,
'Cape_Verde':-3600,
'Caracas':-16200,
'Casablanca':0,
'Casey':28800,
'Catamarca':-10800,
'Cayenne':-10800,
'Cayman':-18000,
'Center':-21600,
'Central':-21600,
'CET':3600,
'Ceuta':3600,
'Chagos':21600,
'Chatham':45900,
'Chicago':-21600,
'Chihuahua':-25200,
'Chisinau':7200,
'Chita':28800,
'Choibalsan':28800,
'Chongqing':28800,
'Christmas':25200,
'Chungking':28800,
'Chuuk':36000,
'Cocos':23400,
'Colombo':19800,
'ComodRivadavia':-10800,
'Comoro':10800,
'Conakry':0,
'Continental':-10800,
'Copenhagen':3600,
'Coral_Harbour':-18000,
'Cordoba':-10800,
'Costa_Rica':-21600,
'Creston':-25200,
'CST6CDT':-21600,
'Cuba':-18000,
'Cuiaba':-14400,
'Curacao':-14400,
'Currie':36000,
'Dacca':21600,
'Dakar':0,
'Damascus':7200,
'Danmarkshavn':0,
'Dar_es_Salaam':10800,
'Darwin':34200,
'Davis':25200,
'Dawson':-28800,
'Dawson_Creek':-25200,
'DeNoronha':-7200,
'Denver':-25200,
'Detroit':-18000,
'Dhaka':21600,
'Dili':32400,
'Djibouti':10800,
'Dominica':-14400,
'Douala':3600,
'Dubai':14400,
'Dublin':0,
'DumontDUrville':36000,
'Dushanbe':18000,
'East':-10800,
'Easter':-18000,
'EasterIsland':-18000,
'Eastern':-18000,
'East-Indiana':-18000,
'East-Saskatchewan':-21600,
'Edmonton':-25200,
'EET':7200,
'Efate':39600,
'Egypt':7200,
'Eire':0,
'Eirunepe':-18000,
'El_Aaiun':0,
'El_Salvador':-21600,
'Enderbury':46800,
'Ensenada':-28800,
'EST':-18000,
'EST5EDT':-18000,
'Eucla':31500,
'Factory':0,
'Faeroe':0,
'Fakaofo':46800,
'Faroe':0,
'Fiji':43200,
'Fort_Nelson':-25200,
'Fort_Wayne':-18000,
'Fortaleza':-10800,
'Freetown':0,
'Funafuti':43200,
'Gaborone':7200,
'Galapagos':-21600,
'Gambier':-32400,
'Gaza':7200,
'GB':0,
'GB-Eire':0,
'General':-21600,
'Gibraltar':3600,
'Glace_Bay':-14400,
'GMT':0,
'GMT+0':0,
'GMT+1':-3600,
'GMT+10':-36000,
'GMT+11':-39600,
'GMT+12':-43200,
'GMT+2':-7200,
'GMT+3':-10800,
'GMT+4':-14400,
'GMT+5':-18000,
'GMT+6':-21600,
'GMT+7':-25200,
'GMT+8':-28800,
'GMT+9':-32400,
'GMT0':0,
'GMT-0':0,
'GMT-1':3600,
'GMT-10':36000,
'GMT-11':39600,
'GMT-12':43200,
'GMT-13':46800,
'GMT-14':50400,
'GMT-2':7200,
'GMT-3':10800,
'GMT-4':14400,
'GMT-5':18000,
'GMT-6':21600,
'GMT-7':25200,
'GMT-8':28800,
'GMT-9':32400,
'Godthab':-10800,
'Goose_Bay':-14400,
'Grand_Turk':-14400,
'Greenwich':0,
'Grenada':-14400,
'Guadalcanal':39600,
'Guadeloupe':-14400,
'Guam':36000,
'Guatemala':-21600,
'Guayaquil':-18000,
'Guernsey':0,
'Guyana':-14400,
'Halifax':-14400,
'Harare':7200,
'Harbin':28800,
'Havana':-18000,
'Hawaii':-36000,
'Hebron':7200,
'Helsinki':7200,
'Hermosillo':-25200,
'Ho_Chi_Minh':25200,
'Hobart':36000,
'Hong_Kong':28800,
'Hongkong':28800,
'Honolulu':-36000,
'Hovd':25200,
'HST':-36000,
'Iceland':0,
'Indianapolis':-18000,
'Indiana-Starke':-21600,
'Inuvik':-25200,
'Iqaluit':-18000,
'Iran':12600,
'Irkutsk':28800,
'Isle_of_Man':0,
'Israel':7200,
'Istanbul':7200,
'Jakarta':25200,
'Jamaica':-18000,
'Jan_Mayen':3600,
'Japan':32400,
'Jayapura':32400,
'Jersey':0,
'Jerusalem':7200,
'Johannesburg':7200,
'Johnston':-36000,
'Juba':10800,
'Jujuy':-10800,
'Juneau':-32400,
'Kabul':16200,
'Kaliningrad':7200,
'Kamchatka':43200,
'Kampala':10800,
'Karachi':18000,
'Kashgar':21600,
'Kathmandu':20700,
'Katmandu':20700,
'Kerguelen':18000,
'Khandyga':32400,
'Khartoum':10800,
'Kiev':7200,
'Kigali':7200,
'Kinshasa':3600,
'Kiritimati':50400,
'Knox':-21600,
'Knox_IN':-21600,
'Kolkata':19800,
'Kosrae':39600,
'Kralendijk':-14400,
'Krasnoyarsk':25200,
'Kuala_Lumpur':28800,
'Kuching':28800,
'Kuwait':10800,
'Kwajalein':43200,
'La_Paz':-14400,
'La_Rioja':-10800,
'Lagos':3600,
'LHI':37800,
'Libreville':3600,
'Libya':7200,
'Lima':-18000,
'Lindeman':36000,
'Lisbon':0,
'Ljubljana':3600,
'Lome':0,
'London':0,
'Longyearbyen':3600,
'Lord_Howe':37800,
'Los_Angeles':-28800,
'Louisville':-18000,
'Lower_Princes':-14400,
'Luanda':3600,
'Lubumbashi':7200,
'Lusaka':7200,
'Luxembourg':3600,
'Macao':28800,
'Macau':28800,
'Maceio':-10800,
'Macquarie':39600,
'Madeira':0,
'Madrid':3600,
'Magadan':36000,
'Mahe':14400,
'Majuro':43200,
'Makassar':28800,
'Malabo':3600,
'Maldives':18000,
'Malta':3600,
'Managua':-21600,
'Manaus':-14400,
'Manila':28800,
'Maputo':7200,
'Marengo':-18000,
'Mariehamn':7200,
'Marigot':-14400,
'Marquesas':-34200,
'Martinique':-14400,
'Maseru':7200,
'Matamoros':-21600,
'Mauritius':14400,
'Mawson':18000,
'Mayotte':10800,
'Mazatlan':-25200,
'Mbabane':7200,
'McMurdo':43200,
'Melbourne':36000,
'Mendoza':-10800,
'Menominee':-21600,
'Merida':-21600,
'MET':3600,
'Metlakatla':-28800,
'Mexico_City':-21600,
'Michigan':-18000,
'Midway':-39600,
'Minsk':10800,
'Miquelon':-10800,
'Mogadishu':10800,
'Monaco':3600,
'Moncton':-14400,
'Monrovia':0,
'Monterrey':-21600,
'Montevideo':-10800,
'Monticello':-18000,
'Montreal':-18000,
'Montserrat':-14400,
'Moscow':10800,
'Mountain':-25200,
'MST':-25200,
'MST7MDT':-25200,
'Muscat':14400,
'Nairobi':10800,
'Nassau':-18000,
'Nauru':43200,
'Navajo':0,
'Ndjamena':3600,
'New_Salem':-21600,
'New_York':-18000,
'Newfoundland':-12600,
'Niamey':3600,
'Nicosia':7200,
'Nipigon':-18000,
'Niue':-39600,
'Nome':-32400,
'Norfolk':39600,
'Noronha':-7200,
'North':34200,
'Nouakchott':0,
'Noumea':39600,
'Novokuznetsk':25200,
'Novosibirsk':21600,
'NSW':36000,
'NZ':43200,
'NZ-CHAT':45900,
'Ojinaga':-25200,
'Omsk':21600,
'Oral':18000,
'Oslo':3600,
'Ouagadougou':0,
'Pacific':-28800,
'Pacific-New':-28800,
'Pago_Pago':-39600,
'Palau':32400,
'Palmer':-10800,
'Panama':-18000,
'Pangnirtung':-18000,
'Paramaribo':-10800,
'Paris':3600,
'Perth':28800,
'Petersburg':-18000,
'Phnom_Penh':25200,
'Phoenix':-25200,
'Pitcairn':-28800,
'Podgorica':3600,
'Poland':3600,
'Ponape':39600,
'Pontianak':25200,
'Port_Moresby':36000,
'Port_of_Spain':-14400,
'Port-au-Prince':-18000,
'Porto_Acre':-18000,
'Porto_Velho':-14400,
'Porto-Novo':3600,
'Portugal':0,
'Prague':3600,
'PRC':0,
'PST8PDT':0,
'Puerto_Rico':-14400,
'Pyongyang':30600,
'Qatar':10800,
'Queensland':36000,
'Qyzylorda':21600,
'Rainy_River':-21600,
'Rangoon':23400,
'Rankin_Inlet':-21600,
'Rarotonga':-36000,
'Recife':-10800,
'Regina':-21600,
'Resolute':-21600,
'Reunion':14400,
'Reykjavik':0,
'Riga':7200,
'Rio_Branco':-18000,
'Rio_Gallegos':-10800,
'Riyadh':10800,
'Riyadh87':10800,
'Riyadh88':10800,
'Riyadh89':10800,
'ROC':28800,
'ROK':32400,
'Rome':3600,
'Rosario':-10800,
'Rothera':-10800,
'Saigon':25200,
'Saipan':36000,
'Sakhalin':36000,
'Salta':-10800,
'Samara':14400,
'Samarkand':18000,
'Samoa':-39600,
'San_Juan':-10800,
'San_Luis':-10800,
'San_Marino':3600,
'Santa_Isabel':-28800,
'Santarem':-10800,
'Santiago':-10800,
'Santo_Domingo':-14400,
'Sao_Paulo':-10800,
'Sao_Tome':0,
'Sarajevo':3600,
'Saskatchewan':-21600,
'Scoresbysund':-3600,
'Seoul':32400,
'Shanghai':28800,
'Shiprock':-25200,
'Simferopol':7200,
'Singapore':28800,
'Sitka':-32400,
'Skopje':3600,
'Sofia':7200,
'South':34200,
'South_Georgia':-7200,
'South_Pole':43200,
'Srednekolymsk':39600,
'St_Barthelemy':-14400,
'St_Helena':0,
'St_Johns':-12600,
'St_Kitts':-14400,
'St_Lucia':-14400,
'St_Thomas':-14400,
'St_Vincent':-14400,
'Stanley':-10800,
'Stockholm':3600,
'Swift_Current':-21600,
'Sydney':36000,
'Syowa':10800,
'Tahiti':-36000,
'Taipei':28800,
'Tallinn':7200,
'Tarawa':43200,
'Tashkent':18000,
'Tasmania':36000,
'Tbilisi':14400,
'Tegucigalpa':-21600,
'Tehran':12600,
'Tel_Aviv':7200,
'Tell_City':-21600,
'Thimbu':21600,
'Thimphu':21600,
'Thule':-14400,
'Thunder_Bay':-18000,
'Tijuana':-28800,
'Timbuktu':0,
'Tirane':3600,
'Tiraspol':7200,
'Tokyo':32400,
'Tongatapu':46800,
'Toronto':-18000,
'Tortola':-14400,
'Tripoli':7200,
'Troll':0,
'Truk':36000,
'Tucuman':-10800,
'Tunis':3600,
'Turkey':7200,
'UCT':0,
'Ujung_Pandang':28800,
'Ulaanbaatar':28800,
'Ulan_Bator':28800,
'Universal':0,
'Urumqi':21600,
'Ushuaia':-10800,
'UTC':0,
'Uzhgorod':7200,
'Vaduz':3600,
'Vancouver':-28800,
'Vatican':3600,
'Vevay':-18000,
'Victoria':36000,
'Vienna':3600,
'Vientiane':25200,
'Vilnius':7200,
'Vincennes':-18000,
'Virgin':-14400,
'Vladivostok':36000,
'Volgograd':10800,
'Vostok':21600,
'Wake':43200,
'Wallis':43200,
'Warsaw':3600,
'West':28800,
'WET':0,
'Whitehorse':-28800,
'Winamac':-18000,
'Windhoek':3600,
'Winnipeg':-21600,
'W-SU':10800,
'Yakutat':-32400,
'Yakutsk':32400,
'Yancowinna':34200,
'Yap':36000,
'Yekaterinburg':18000,
'Yellowknife':-25200,
'Yerevan':14400,
'Yukon':-28800,
'Zagreb':3600,
'Zaporozhye':7200,
'Zulu':0,
'Zurich':3600
}

monList = {'Jul':7,'Aug':8,'Sep':9}
estOffset = -18000

# %%
monthList = ['July','July','July','July','July','July','July','July','August','August','August','August','August','August',
             'August','August','September','September','September','September','September','September','September',
             'September','September','September','September','September']

dateList = ['07-Jul','08-Jul','07-Jul','08-Jul','21-Jul','21-Jul','22-Jul','22-Jul','04-Aug','04-Aug','05-Aug','05-Aug',
            '18-Aug','18-Aug','19-Aug','19-Aug','01-Sep','01-Sep','02-Sep','02-Sep','15-Sep','15-Sep','16-Sep','16-Sep',
            '29-Sep','29-Sep','30-Sep','30-Sep']
            
timeList = ['6.00AM','10.00AM','6.00AM','10.00AM','6.00AM','10.00AM','6.00AM','10.00AM','6.00AM','10.00AM','6.00AM',
            '10.00AM','6.00AM','10.00AM','6.00AM','10.00AM','6.00AM','10.00AM','6.00AM','10.00AM','6.00AM','10.00AM',
            '6.00AM','10.00AM','6.00AM','10.00AM','6.00AM','10.00AM']
            
cohortList = ['Cohort 14','Cohort 15','Cohort 14','Cohort 15','Cohort 14','Cohort 15','Cohort 14','Cohort 15','Cohort 14',
              'Cohort 15','Cohort 14','Cohort 15','Cohort 14','Cohort 15','Cohort 14','Cohort 15','Cohort 14','Cohort 15',
              'Cohort 14','Cohort 15','Cohort 14','Cohort 15','Cohort 14','Cohort 15','Cohort 14','Cohort 15','Cohort 14',
              'Cohort 15']
            
programList = ['Data Analytics','Data Science/ML','Data Science/ML','Data Analytics','Data Analytics','Data Science/ML',
               'Data Science/ML','Data Analytics','Data Analytics','Data Science/ML','Data Science/ML','Data Analytics',
               'Data Analytics','Data Science/ML','Data Science/ML','Data Analytics','Data Analytics','Data Science/ML',
               'Data Science/ML','Data Analytics','Data Analytics','Data Science/ML','Data Science/ML','Data Analytics',
               'Data Analytics','Data Science/ML','Data Science/ML','Data Analytics']
            
topicList = ['Python Variables','Data Cleaning','Python Variables','Data Visualization Project 1','Python Container',
             'Data Transformation','Python Container','Data Visualization Project 2','Python Container II',
             'Data Transformation II','Python Container II','Data Visualization Project 3','Python Functions',
             'Feature Selection','Python Functions','Data Visualization Project 4','Python Functions',
             'Feature Selection II','Python Functions II','Data Visualization Project 5','Python Pandas I',
             'Supervised Learning Intro','Python Pandas I','Data Visualization Project 6','Python Pandas II',
             'Unsupervised Learning Intro','Python Pandas II','Data Visualization Project 7']

# %%
for m, dte,t,cohort,prog, topic in zip(monthList,dateList,timeList,cohortList,programList,topicList):
    print(m, dte,t,cohort,prog, topic)
# Out:
# July 07-Jul 6.00AM Cohort 14 Data Analytics Python Variables
# July 08-Jul 10.00AM Cohort 15 Data Science/ML Data Cleaning
# July 07-Jul 6.00AM Cohort 14 Data Science/ML Python Variables
# July 08-Jul 10.00AM Cohort 15 Data Analytics Data Visualization Project 1
# July 21-Jul 6.00AM Cohort 14 Data Analytics Python Container
# July 21-Jul 10.00AM Cohort 15 Data Science/ML Data Transformation
# July 22-Jul 6.00AM Cohort 14 Data Science/ML Python Container
# July 22-Jul 10.00AM Cohort 15 Data Analytics Data Visualization Project 2
# August 04-Aug 6.00AM Cohort 14 Data Analytics Python Container II
# August 04-Aug 10.00AM Cohort 15 Data Science/ML Data Transformation II
# August 05-Aug 6.00AM Cohort 14 Data Science/ML Python Container II
# August 05-Aug 10.00AM Cohort 15 Data Analytics Data Visualization Project 3
# August 18-Aug 6.00AM Cohort 14 Data Analytics Python Functions
# August 18-Aug 10.00AM Cohort 15 Data Science/ML Feature Selection
# ...

# %%
userCity = input('Input your City')
userTime = input('Input Bootcamp Time - format: xx.xxAM')
userDate = input('Input Bootcamp Date - format: DD-MMM')
userCohort = input('Input your Cohort - format: Cohort xx')
userProgram = input('Input your Program - format: (Data Analytics, Data Science/ML)')

def userHrs():
    # Checking if last two elements of time
    # is AM and first two elements are 12
    if userTime[-2:] == "AM" and userTime[:2] in timeList:
        return "00" + userTime[2:-2]
         
    # remove the AM    
    elif userTime[-2:] == "AM":
        return userTime[:-2]
     
    # Checking if last two elements of time
    # is PM and first two elements are 12
    elif userTime[-2:] == "PM" and userTime[:2] in timeList:
        return userTime[:-2]
         
    else:
         
        # add 12 to hours and remove PM
        return str(int(userTime[:2]) + 12) + userTime[2:5]
    
    trimTime = userHrs().split('.')
    hr = int(trimTime[0])    
    return hr

hrSecs = int(float(userHrs()[:2]))*60*60

est_UTC = hrSecs + abs(estOffset)

if userCity in list(countryTimes.keys()):
    countryOffset = countryTimes[userCity]
    
convertedTime = est_UTC + countryTimes[userCity]

newHr = float(convertedTime/60/60)
convHr = int(newHr)

if convHr < 0:
    convHr = 24-int(abs(newHr))

if convHr == 24:
    convHr = 0
elif convHr >24:
    convHr = 0+1
else:
    convHr


newMin = str(newHr).split('.')
nnn = int(newMin[1])
if nnn >10:
    convMin = int(nnn * 0.6)
elif nnn >=5 <10:
    convMin = nnn * 0.6
    print(int(convMin))
else:
    convMin = int(nnn)

def dateEntry():
    trimDate = userDate.split('-')
    dateDay = int(trimDate[0])
    dateMon = trimDate[1]
    return dateDay, dateMon

dateEntry()

month = dateEntry()[1]
day = dateEntry()[0]
if month in list(monList.keys()):
    nMon = int(monList[month])
if int(newHr) == 24:
    day = dateEntry()[0] + 1
elif int(newHr) >24:
    day = dateEntry()[0] + 1
else:
    day
    
bootcampTime = datetime.datetime(2022, nMon, day, convHr, convMin)

if userCity not in countryTimes.keys():
    print('City not available')
else:
    pass

if userTime not in timeList:
    ('Enter a correct time')
else:
    pass

if userDate in dateList:
    dateIndex = dateList.index(userDate)
else:
    print('Enter a correct date')

if userCohort in cohortList:
    cohortIndex = cohortList.index(userCohort)
else:
    print('Enter a correct Cohort')
    
if userProgram in programList:
    programIndex = programList.index(userProgram)
else:
    print('Enter a correct Program')

if dateIndex == cohortIndex == programIndex:
    print (f'Your bootcamp for {programList[programIndex]}, {cohortList[cohortIndex]} in {userCity} timezone on (24hrs clock) is scheduled for {bootcampTime}, the session will focus on {topicList[dateIndex]} Cheers!!!')
# Out:
# Input your CityLagos
# Input Bootcamp Time - format: xx.xxAM10.10AM
# Input Bootcamp Date - format: DD-MMM02-05
# Input your Cohort - format: Cohort xxCohort 15
